# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/gpt_from_scracth/blob/main/gpt_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instalação de bibliotecas

# %%
# !pip install torch
# !pip install typing
# !pip install pydantic
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: typing in /usr/local/lib/python3.11/dist-packages (3.7.4.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (2.11.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic) (0.4.1)

# %% [markdown]
# Primeira versão, básica. Sem córtex pré-frontal

# %%
import numpy as np
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from typing import List
from pydantic import BaseModel

class GPTInput(BaseModel):
    text: str

class GPT:
    # Mover os métodos para dentro da classe GPT com a indentação correta
    def init(self, caracteres: str):
        self.raw_text = caracteres
        self.tokens = self.tokenize(caracteres)
        self.vocab = list(set(self.tokens))
        self.token_to_idx = {ch: i for i, ch in enumerate(self.vocab)}
        self.idx_to_token = {i: ch for ch, i in self.token_to_idx.items()}
        self.encoded = self.encode(self.tokens)
        self.embedding_dim = 16
        self.embeddings = self.init_embeddings(len(self.vocab), self.embedding_dim)
        self.weights_q = self.init_weights()
        self.weights_k = self.init_weights()
        self.weights_v = self.init_weights()
        self.positional_encoding = self.get_positional_encoding(len(self.encoded), self.embedding_dim)
        self.ffn1 = torch.nn.Linear(self.embedding_dim, self.embedding_dim)
        self.ffn2 = torch.nn.Linear(self.embedding_dim, self.embedding_dim)

    def tokenize(self, text: str) -> List[str]:
        return list(text)

    def encode(self, tokens: List[str]) -> List[int]:
        return [self.token_to_idx[tok] for tok in tokens]

    def init_embeddings(self, vocab_size: int, dim: int):
        return torch.randn(vocab_size, dim, requires_grad=True)

    def init_weights(self):
        return torch.randn(self.embedding_dim, self.embedding_dim, requires_grad=True)

    def get_positional_encoding(self, seq_len: int, dim: int):
        pe = torch.zeros(seq_len, dim)
        for pos in range(seq_len):
            for i in range(0, dim, 2):
                pe[pos, i] = math.sin(pos / (10000 ** ((2 * i)/dim)))
                if i + 1 < dim:
                    pe[pos, i + 1] = math.cos(pos / (10000 ** ((2 * i)/dim)))
        return pe

    def embed(self, encoded: List[int]):
        x = torch.stack([self.embeddings[idx] for idx in encoded])
        x += self.positional_encoding
        return x

    def attention(self, x: torch.Tensor):
        Q = x @ self.weights_q
        K = x @ self.weights_k
        V = x @ self.weights_v

        dk = Q.size(-1)
        scores = (Q @ K.transpose(-2, -1)) / math.sqrt(dk)
        weights = F.softmax(scores, dim=-1)
        attended = weights @ V

        # Cálculo simbólico do número de arranjos com repetição
        n = Q.shape[0]
        num_arranjos = n ** 2
        print(f"Número de arranjos com repetição em atenção: {num_arranjos}")

        # Cálculo de combinações ponderadas entre posições Q e V
        for i in range(n):
            for j in range(n):
                prob = weights[i, j].item()
                print(f"Probabilidade de atenção do token {i} para {j}: {prob:.4f}")

        return attended

    def feed_forward(self, x):
        x = F.relu(self.ffn1(x))
        return self.ffn2(x)

    def forward(self):
        x = self.embed(self.encoded)
        x = self.attention(x)
        x = self.feed_forward(x)
        return x

    def train_step(self, target: torch.Tensor, optimizer):
        output = self.forward()
        loss = F.mse_loss(output, target)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        return loss.item()

    def validate(self):
        # Validação Bayesiana (simulação simples)
        print("Validação Bayesiana placeholder: usando heurísticas de incerteza para ajustar hiperparâmetros")
        return {
            "melhor_lr": 0.001,
            "melhor_batch_size": 8,
            "incerteza_modelo": 0.12
        }

    def retrain(self, target: torch.Tensor):
        print("Reiniciando com hiperparâmetros otimizados")
        opt = torch.optim.Adam([self.embeddings], lr=0.001)
        for i in range(10):
            loss = self.train_step(target, opt)
            print(f"Iteração {i+1} - Loss: {loss:.4f}")

# Exemplo de uso:

entrada = GPTInput(text="transformer")
# Note: The __init__ method should be defined as __init__ not init
modelo = GPT()
modelo.init(entrada.text)
target = torch.randn(len(modelo.encoded), modelo.embedding_dim)
modelo.retrain(target)
saida = modelo.forward()
print(saida)
# Out:
# Reiniciando com hiperparâmetros otimizados
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 0.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 1.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 1.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 0.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.1226
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.0000
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0000
# Probabilidade de atenção do token 2 para 6: 0.8721
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0003
# Probabilidade de atenção do token 2 para 9: 0.0049
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.0000
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0166
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.9342
# Probabilidade de atenção do token 3 para 6: 0.0000
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0492
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 1.0000
# Probabilidade de atenção do token 4 para 4: 0.0000
# Probabilidade de atenção do token 4 para 5: 0.0000
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.0000
# Probabilidade de atenção do token 5 para 0: 0.1792
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.1762
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0205
# Probabilidade de atenção do token 5 para 5: 0.0019
# Probabilidade de atenção do token 5 para 6: 0.6181
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0041
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 1.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0000
# Probabilidade de atenção do token 6 para 5: 0.0000
# Probabilidade de atenção do token 6 para 6: 0.0000
# Probabilidade de atenção do token 6 para 7: 0.0000
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0000
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 1.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 0.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 0.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0001
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.9179
# Probabilidade de atenção do token 8 para 10: 0.0818
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 0.0000
# Probabilidade de atenção do token 9 para 6: 0.0002
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.9998
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 1.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 0.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 1 - Loss: 1.9699
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 0.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 1.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 1.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 0.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.1401
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.0000
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0000
# Probabilidade de atenção do token 2 para 6: 0.8546
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0003
# Probabilidade de atenção do token 2 para 9: 0.0050
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.0000
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0166
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.9327
# Probabilidade de atenção do token 3 para 6: 0.0000
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0506
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 1.0000
# Probabilidade de atenção do token 4 para 4: 0.0000
# Probabilidade de atenção do token 4 para 5: 0.0000
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.0000
# Probabilidade de atenção do token 5 para 0: 0.1896
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.1628
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0199
# Probabilidade de atenção do token 5 para 5: 0.0019
# Probabilidade de atenção do token 5 para 6: 0.6214
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0043
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 1.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0000
# Probabilidade de atenção do token 6 para 5: 0.0000
# Probabilidade de atenção do token 6 para 6: 0.0000
# Probabilidade de atenção do token 6 para 7: 0.0000
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0000
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 1.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 0.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 0.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0002
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.8965
# Probabilidade de atenção do token 8 para 10: 0.1032
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 0.0000
# Probabilidade de atenção do token 9 para 6: 0.0001
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.9998
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 1.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 0.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 2 - Loss: 1.9618
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 0.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 1.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 1.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 0.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.1604
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.0000
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0000
# Probabilidade de atenção do token 2 para 6: 0.8342
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0003
# Probabilidade de atenção do token 2 para 9: 0.0051
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.0000
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0168
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.9309
# Probabilidade de atenção do token 3 para 6: 0.0000
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0523
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 1.0000
# Probabilidade de atenção do token 4 para 4: 0.0000
# Probabilidade de atenção do token 4 para 5: 0.0000
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.0000
# Probabilidade de atenção do token 5 para 0: 0.1986
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.1526
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0194
# Probabilidade de atenção do token 5 para 5: 0.0019
# Probabilidade de atenção do token 5 para 6: 0.6228
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0047
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 1.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0000
# Probabilidade de atenção do token 6 para 5: 0.0000
# Probabilidade de atenção do token 6 para 6: 0.0000
# Probabilidade de atenção do token 6 para 7: 0.0000
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0000
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 1.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 0.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0001
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 0.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0002
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.8702
# Probabilidade de atenção do token 8 para 10: 0.1295
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 0.0000
# Probabilidade de atenção do token 9 para 6: 0.0001
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.9998
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 1.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 0.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 3 - Loss: 1.9532
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 0.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 1.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 1.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 0.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.1831
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.0000
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0000
# Probabilidade de atenção do token 2 para 6: 0.8112
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0003
# Probabilidade de atenção do token 2 para 9: 0.0053
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.0000
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0169
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.9287
# Probabilidade de atenção do token 3 para 6: 0.0000
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0544
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 1.0000
# Probabilidade de atenção do token 4 para 4: 0.0000
# Probabilidade de atenção do token 4 para 5: 0.0000
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.0000
# Probabilidade de atenção do token 5 para 0: 0.2071
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.1440
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0190
# Probabilidade de atenção do token 5 para 5: 0.0019
# Probabilidade de atenção do token 5 para 6: 0.6230
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0050
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 1.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0000
# Probabilidade de atenção do token 6 para 5: 0.0000
# Probabilidade de atenção do token 6 para 6: 0.0000
# Probabilidade de atenção do token 6 para 7: 0.0000
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0000
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 1.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 0.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0001
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 0.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0003
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.8384
# Probabilidade de atenção do token 8 para 10: 0.1613
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 0.0000
# Probabilidade de atenção do token 9 para 6: 0.0001
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.9998
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 1.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 0.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 4 - Loss: 1.9446
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 0.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 1.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 1.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 0.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.2084
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.0000
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0000
# Probabilidade de atenção do token 2 para 6: 0.7858
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0004
# Probabilidade de atenção do token 2 para 9: 0.0054
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.0000
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0171
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.9261
# Probabilidade de atenção do token 3 para 6: 0.0000
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0567
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 1.0000
# Probabilidade de atenção do token 4 para 4: 0.0000
# Probabilidade de atenção do token 4 para 5: 0.0000
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.0000
# Probabilidade de atenção do token 5 para 0: 0.2152
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.1367
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0186
# Probabilidade de atenção do token 5 para 5: 0.0019
# Probabilidade de atenção do token 5 para 6: 0.6223
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0053
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 1.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0000
# Probabilidade de atenção do token 6 para 5: 0.0000
# Probabilidade de atenção do token 6 para 6: 0.0000
# Probabilidade de atenção do token 6 para 7: 0.0000
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0000
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 1.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 0.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0001
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 0.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0003
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.8010
# Probabilidade de atenção do token 8 para 10: 0.1986
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 0.0000
# Probabilidade de atenção do token 9 para 6: 0.0001
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.9998
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 1.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 0.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 5 - Loss: 1.9375
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 0.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 1.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 1.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 0.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.2347
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.0000
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0000
# Probabilidade de atenção do token 2 para 6: 0.7594
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0004
# Probabilidade de atenção do token 2 para 9: 0.0054
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.0000
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0172
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.9234
# Probabilidade de atenção do token 3 para 6: 0.0000
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0594
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 1.0000
# Probabilidade de atenção do token 4 para 4: 0.0000
# Probabilidade de atenção do token 4 para 5: 0.0000
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.0000
# Probabilidade de atenção do token 5 para 0: 0.2221
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.1302
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0183
# Probabilidade de atenção do token 5 para 5: 0.0019
# Probabilidade de atenção do token 5 para 6: 0.6219
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0056
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 1.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0000
# Probabilidade de atenção do token 6 para 5: 0.0000
# Probabilidade de atenção do token 6 para 6: 0.0000
# Probabilidade de atenção do token 6 para 7: 0.0000
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0000
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 1.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 0.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0001
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 0.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0004
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.7580
# Probabilidade de atenção do token 8 para 10: 0.2415
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 0.0000
# Probabilidade de atenção do token 9 para 6: 0.0001
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.9999
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 1.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 0.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 6 - Loss: 1.9315
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 0.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 1.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 1.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 0.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.2613
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.0000
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0000
# Probabilidade de atenção do token 2 para 6: 0.7328
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0004
# Probabilidade de atenção do token 2 para 9: 0.0054
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.0000
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0174
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.9203
# Probabilidade de atenção do token 3 para 6: 0.0000
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0622
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 1.0000
# Probabilidade de atenção do token 4 para 4: 0.0000
# Probabilidade de atenção do token 4 para 5: 0.0000
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.0000
# Probabilidade de atenção do token 5 para 0: 0.2276
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.1242
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0181
# Probabilidade de atenção do token 5 para 5: 0.0019
# Probabilidade de atenção do token 5 para 6: 0.6223
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0059
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 1.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0000
# Probabilidade de atenção do token 6 para 5: 0.0000
# Probabilidade de atenção do token 6 para 6: 0.0000
# Probabilidade de atenção do token 6 para 7: 0.0000
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0000
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 1.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 0.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0001
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0001
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 0.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0004
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.7103
# Probabilidade de atenção do token 8 para 10: 0.2891
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 0.0000
# Probabilidade de atenção do token 9 para 6: 0.0001
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.9999
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 1.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 0.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 7 - Loss: 1.9267
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 0.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 1.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 1.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 0.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.2868
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.0000
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0000
# Probabilidade de atenção do token 2 para 6: 0.7073
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0005
# Probabilidade de atenção do token 2 para 9: 0.0054
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.0000
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0175
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.9171
# Probabilidade de atenção do token 3 para 6: 0.0000
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0654
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 1.0000
# Probabilidade de atenção do token 4 para 4: 0.0000
# Probabilidade de atenção do token 4 para 5: 0.0000
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.0000
# Probabilidade de atenção do token 5 para 0: 0.2314
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.1186
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0179
# Probabilidade de atenção do token 5 para 5: 0.0019
# Probabilidade de atenção do token 5 para 6: 0.6240
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0062
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 1.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0000
# Probabilidade de atenção do token 6 para 5: 0.0000
# Probabilidade de atenção do token 6 para 6: 0.0000
# Probabilidade de atenção do token 6 para 7: 0.0000
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0000
# Probabilidade de atenção do token 7 para 0: 0.0000
# ...
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0001
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 0.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0006
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.6140
# Probabilidade de atenção do token 8 para 10: 0.3852
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 0.0000
# Probabilidade de atenção do token 9 para 6: 0.0001
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.9999
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 1.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 0.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 9 - Loss: 1.9219
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 0.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 1.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 1.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 0.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.3287
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.0000
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0000
# Probabilidade de atenção do token 2 para 6: 0.6654
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0005
# Probabilidade de atenção do token 2 para 9: 0.0053
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.0000
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0176
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.9100
# Probabilidade de atenção do token 3 para 6: 0.0000
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0723
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 1.0000
# Probabilidade de atenção do token 4 para 4: 0.0000
# Probabilidade de atenção do token 4 para 5: 0.0000
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.0000
# Probabilidade de atenção do token 5 para 0: 0.2325
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.1081
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0179
# Probabilidade de atenção do token 5 para 5: 0.0019
# Probabilidade de atenção do token 5 para 6: 0.6330
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0066
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 1.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0000
# Probabilidade de atenção do token 6 para 5: 0.0000
# Probabilidade de atenção do token 6 para 6: 0.0000
# Probabilidade de atenção do token 6 para 7: 0.0000
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0000
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 1.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 0.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0001
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0001
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 0.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0006
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.5762
# Probabilidade de atenção do token 8 para 10: 0.4229
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 0.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.9999
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 1.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 0.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 10 - Loss: 1.9211
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 0.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 1.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 1.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 0.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.3425
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.0000
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0000
# Probabilidade de atenção do token 2 para 6: 0.6516
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0005
# Probabilidade de atenção do token 2 para 9: 0.0053
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.0000
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0176
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.9062
# Probabilidade de atenção do token 3 para 6: 0.0000
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0762
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 1.0000
# Probabilidade de atenção do token 4 para 4: 0.0000
# Probabilidade de atenção do token 4 para 5: 0.0000
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.0000
# Probabilidade de atenção do token 5 para 0: 0.2298
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.1031
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0181
# Probabilidade de atenção do token 5 para 5: 0.0018
# Probabilidade de atenção do token 5 para 6: 0.6405
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0068
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 1.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0000
# Probabilidade de atenção do token 6 para 5: 0.0000
# Probabilidade de atenção do token 6 para 6: 0.0000
# Probabilidade de atenção do token 6 para 7: 0.0000
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0000
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 1.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 0.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0002
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0001
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 0.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0007
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.5508
# Probabilidade de atenção do token 8 para 10: 0.4483
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 0.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.9999
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 1.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 0.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# tensor([[-1.1506,  3.6411, -1.3148,  0.0165, -0.2271,  0.1063,  1.0714, -1.9872,
#          -1.1249,  0.2419, -2.1040,  1.2548,  0.6226, -1.5078,  0.1566, -0.3591],
#         [-0.6709,  1.4673,  0.0630,  0.1686,  1.2212,  0.3129, -1.7455, -0.3606,
#          -1.2582, -0.1039, -0.5493, -0.8116, -0.1329, -0.9089, -0.9327,  1.5468],
#         [-0.5629,  0.7708, -1.2225,  0.2577,  0.0801, -0.4500,  0.8460, -1.2338,
#          -0.2262, -0.7254, -0.8168,  0.8854,  0.7650, -0.0687,  0.6917,  0.8024],
#         [-0.3585,  0.2756, -0.8459, -0.5413,  0.7631, -0.6295, -0.0407, -0.5259,
#          -1.2123, -1.0497, -0.2746,  0.4191,  0.4888, -0.9971, -0.3507,  1.5362],
#         [-0.6709,  1.4673,  0.0630,  0.1686,  1.2212,  0.3129, -1.7455, -0.3606,
#          -1.2582, -0.1039, -0.5493, -0.8116, -0.1329, -0.9089, -0.9327,  1.5468],
#         [-0.5291,  0.4440, -1.0339, -0.0942,  0.4197, -0.5567,  0.4994, -0.8809,
#          -0.5690, -0.7848, -0.4935,  0.6677,  0.8338, -0.2480,  0.3713,  1.0621],
#         [ 0.4592, -0.3384, -0.2959, -1.9292,  0.8261, -1.2931, -0.3921,  0.4443,
#          -3.4142, -1.5263,  0.4644,  0.2294,  1.2773, -2.7465, -1.5656,  1.9343],
#         [-0.6709,  1.4673,  0.0630,  0.1686,  1.2212,  0.3129, -1.7455, -0.3606,
#          -1.2582, -0.1039, -0.5493, -0.8116, -0.1329, -0.9089, -0.9327,  1.5468],
#         [ 0.4604,  3.3608, -0.5916,  0.0574,  0.3228,  0.2155,  0.8405, -0.5168,
#          -0.9093,  0.9728, -0.4922,  0.6586,  1.5469, -1.3702,  0.2580, -0.7253],
#         [ 1.7235,  2.9014, -0.5619, -0.2889,  1.6679, -0.1388,  0.8598,  0.9729,
#          -0.7592,  0.9932,  1.0819,  0.3122,  2.4576, -1.3991,  0.3631, -0.2375],
#         [-0.6709,  1.4673,  0.0630,  0.1686,  1.2212,  0.3129, -1.7455, -0.3606,
#          -1.2582, -0.1039, -0.5493, -0.8116, -0.1329, -0.9089, -0.9327,  1.5468]],
#        grad_fn=<AddmmBackward0>)

# %% [markdown]
# Segunda versão, já com a arquitetura base token + embedding - posicional enconding - self attention - attention - multi head attention (mha) - ferro forward neural netowork (ffn) - resíduos e camadas de normalização. Inclui a tomada de decisão via córtex pré-frontal

# %%
import numpy as np
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from typing import List
from pydantic import BaseModel

class GPTInput(BaseModel):
    text: str

class MiniPrefrontalCortex:
    # Adicionar um linear layer para mapear de embedding_dim para o número de ações
    def __init__(self, actions, embedding_dim, temperature=1.0, top_k=None):
        self.actions = actions
        self.num_actions = len(actions)
        self.temperature = temperature
        self.top_k = top_k
        # Linear layer para mapear a saída do modelo para o espaço de ações
        self.decision_layer = nn.Linear(embedding_dim, self.num_actions)

    def softmax(self, logits):
        # Aplicar a camada linear antes do softmax
        action_logits = self.decision_layer(torch.from_numpy(logits)).detach().numpy()
        scaled_logits = action_logits / self.temperature
        exps = np.exp(scaled_logits - np.max(scaled_logits))
        return exps / np.sum(exps)

    def apply_top_k(self, probs):
        if self.top_k is None or self.top_k >= len(probs):
            return probs
        # Certificar-se de que top_k não excede o número real de ações
        actual_top_k = min(self.top_k, len(probs))
        indices = np.argpartition(probs, -actual_top_k)[-actual_top_k:]
        mask = np.zeros_like(probs)
        mask[indices] = 1
        filtered = probs * mask
        # Normalizar as probabilidades filtradas
        return filtered / np.sum(filtered) if np.sum(filtered) > 0 else np.ones_like(probs) / len(probs)


    def decide(self, logits):
        probs = self.softmax(logits)
        probs = self.apply_top_k(probs)
        # np.random.choice requer que a soma das probabilidades seja 1 (ou muito próxima)
        # e que o tamanho de p seja igual ao de a.
        # Garantir que a soma seja 1 para evitar erros
        probs = probs / np.sum(probs) if np.sum(probs) > 0 else np.ones_like(probs) / len(probs)
        action_idx = np.random.choice(self.num_actions, p=probs)
        return self.actions[action_idx], probs

class GPT:
    def __init__(self, caracteres: str):
        self.raw_text = caracteres
        self.tokens = self.tokenize(caracteres)
        self.vocab = list(set(self.tokens))
        self.token_to_idx = {ch: i for i, ch in enumerate(self.vocab)}
        self.idx_to_token = {i: ch for ch, i in self.token_to_idx.items()}
        self.encoded = self.encode(self.tokens)
        self.embedding_dim = 16
        self.embeddings = self.init_embeddings(len(self.vocab), self.embedding_dim)
        self.weights_q = self.init_weights()
        self.weights_k = self.init_weights()
        self.weights_v = self.init_weights()
        self.positional_encoding = self.get_positional_encoding(len(self.encoded), self.embedding_dim)
        self.ffn1 = torch.nn.Linear(self.embedding_dim, self.embedding_dim)
        self.ffn2 = torch.nn.Linear(self.embedding_dim, self.embedding_dim)

        # Mini-córtex com ações possíveis, passando o embedding_dim
        self.actions = ["Gerar Próximo Token", "Revisar Saída", "Aumentar Atenção", "Reduzir Atenção", "Finalizar"]
        self.mini_cortex = MiniPrefrontalCortex(self.actions, self.embedding_dim, temperature=1.0, top_k=3)


    def tokenize(self, text: str) -> List[str]:
        return list(text)

    def encode(self, tokens: List[str]) -> List[int]:
        return [self.token_to_idx[tok] for tok in tokens]

    def init_embeddings(self, vocab_size: int, dim: int):
        return torch.randn(vocab_size, dim, requires_grad=True)

    def init_weights(self):
        return torch.randn(self.embedding_dim, self.embedding_dim, requires_grad=True)

    def get_positional_encoding(self, seq_len: int, dim: int):
        pe = torch.zeros(seq_len, dim)
        for pos in range(seq_len):
            for i in range(0, dim, 2):
                pe[pos, i] = math.sin(pos / (10000 ** ((2 * i)/dim)))
                if i + 1 < dim:
                    pe[pos, i + 1] = math.cos(pos / (10000 ** ((2 * i)/dim)))
        return pe

    def embed(self, encoded: List[int]):
        x = torch.stack([self.embeddings[idx] for idx in encoded])
        x += self.positional_encoding
        return x

    def attention(self, x: torch.Tensor):
        Q = x @ self.weights_q
        K = x @ self.weights_k
        V = x @ self.weights_v

        dk = Q.size(-1)
        scores = (Q @ K.transpose(-2, -1)) / math.sqrt(dk)
        weights = F.softmax(scores, dim=-1)
        attended = weights @ V

        n = Q.shape[0]
        num_arranjos = n ** 2
        print(f"Número de arranjos com repetição em atenção: {num_arranjos}")
        for i in range(n):
            for j in range(n):
                prob = weights[i, j].item()
                print(f"Probabilidade de atenção do token {i} para {j}: {prob:.4f}")

        return attended

    def feed_forward(self, x):
        x = F.relu(self.ffn1(x))
        return self.ffn2(x)

    def forward(self):
        x = self.embed(self.encoded)
        x = self.attention(x)
        x = self.feed_forward(x)
        return x

    def decide_with_prefrontal(self):
        output = self.forward()
        # Média sobre a dimensão da sequência para obter um tensor [embedding_dim]
        logits_for_decision = output.mean(dim=0).detach().numpy()
        # Passar os logits para o mini-córtex para decidir a ação
        action, probs = self.mini_cortex.decide(logits_for_decision)
        print(f"Ação decidida pelo MiniCórtex: {action}")
        print(f"Distribuição de probabilidades: {np.round(probs,3)}")
        return action, probs


    def train_step(self, target: torch.Tensor, optimizer):
        output = self.forward()
        loss = F.mse_loss(output, target)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        return loss.item()

    def retrain(self, target: torch.Tensor):
        print("Reiniciando com hiperparâmetros otimizados")
        opt = torch.optim.Adam([self.embeddings, *self.mini_cortex.decision_layer.parameters()], lr=0.001) # Incluir os parâmetros da camada de decisão
        for i in range(10):
            loss = self.train_step(target, opt)
            print(f"Iteração {i+1} - Loss: {loss:.4f}")

# Uso exemplo
entrada = GPTInput(text="transformer")
modelo = GPT(entrada.text)
target = torch.randn(len(modelo.encoded), modelo.embedding_dim)
modelo.retrain(target)

# Decisão do mini-córtex integrada
action, probs = modelo.decide_with_prefrontal()
# Out:
# Reiniciando com hiperparâmetros otimizados
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 1.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 0.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 0.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 1.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.0000
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.9585
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0194
# Probabilidade de atenção do token 2 para 6: 0.0000
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0221
# Probabilidade de atenção do token 2 para 9: 0.0000
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.1303
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0000
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.7671
# Probabilidade de atenção do token 3 para 6: 0.1026
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0000
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 0.0000
# Probabilidade de atenção do token 4 para 4: 0.4235
# Probabilidade de atenção do token 4 para 5: 0.0095
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.5670
# Probabilidade de atenção do token 5 para 0: 0.0000
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.0000
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0000
# Probabilidade de atenção do token 5 para 5: 1.0000
# Probabilidade de atenção do token 5 para 6: 0.0000
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0000
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 0.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0227
# Probabilidade de atenção do token 6 para 5: 0.9313
# Probabilidade de atenção do token 6 para 6: 0.0026
# Probabilidade de atenção do token 6 para 7: 0.0002
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0432
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 0.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 1.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 1.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0000
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.0000
# Probabilidade de atenção do token 8 para 10: 0.0000
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 1.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.0000
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 0.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 1.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 1 - Loss: 1.8593
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 1.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 0.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 0.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 1.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.0000
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.9543
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0213
# Probabilidade de atenção do token 2 para 6: 0.0000
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0244
# Probabilidade de atenção do token 2 para 9: 0.0000
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.1574
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0000
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.7214
# Probabilidade de atenção do token 3 para 6: 0.1212
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0000
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 0.0000
# Probabilidade de atenção do token 4 para 4: 0.4405
# Probabilidade de atenção do token 4 para 5: 0.0097
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.5498
# Probabilidade de atenção do token 5 para 0: 0.0000
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.0000
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0000
# Probabilidade de atenção do token 5 para 5: 1.0000
# Probabilidade de atenção do token 5 para 6: 0.0000
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0000
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 0.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0242
# Probabilidade de atenção do token 6 para 5: 0.9279
# Probabilidade de atenção do token 6 para 6: 0.0027
# Probabilidade de atenção do token 6 para 7: 0.0002
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0450
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 0.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 1.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 1.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0000
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.0000
# Probabilidade de atenção do token 8 para 10: 0.0000
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 1.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.0000
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 0.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 1.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 2 - Loss: 1.8515
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 1.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 0.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 0.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 1.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.0000
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.9496
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0234
# Probabilidade de atenção do token 2 para 6: 0.0000
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0269
# Probabilidade de atenção do token 2 para 9: 0.0000
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.1881
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0000
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.6705
# Probabilidade de atenção do token 3 para 6: 0.1415
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0000
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 0.0000
# Probabilidade de atenção do token 4 para 4: 0.4566
# Probabilidade de atenção do token 4 para 5: 0.0100
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.5334
# Probabilidade de atenção do token 5 para 0: 0.0000
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.0000
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0000
# Probabilidade de atenção do token 5 para 5: 1.0000
# Probabilidade de atenção do token 5 para 6: 0.0000
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0000
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 0.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0257
# Probabilidade de atenção do token 6 para 5: 0.9243
# Probabilidade de atenção do token 6 para 6: 0.0029
# Probabilidade de atenção do token 6 para 7: 0.0002
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0470
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 0.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 1.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 1.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0000
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.0000
# Probabilidade de atenção do token 8 para 10: 0.0000
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 1.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.0000
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 0.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 1.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 3 - Loss: 1.8433
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 1.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 0.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 0.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 1.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.0000
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.9446
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0258
# Probabilidade de atenção do token 2 para 6: 0.0000
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0297
# Probabilidade de atenção do token 2 para 9: 0.0000
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.2220
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0000
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.6154
# Probabilidade de atenção do token 3 para 6: 0.1626
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0000
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 0.0000
# Probabilidade de atenção do token 4 para 4: 0.4717
# Probabilidade de atenção do token 4 para 5: 0.0103
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.5180
# Probabilidade de atenção do token 5 para 0: 0.0000
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.0000
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0000
# Probabilidade de atenção do token 5 para 5: 1.0000
# Probabilidade de atenção do token 5 para 6: 0.0000
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0000
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 0.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0273
# Probabilidade de atenção do token 6 para 5: 0.9200
# Probabilidade de atenção do token 6 para 6: 0.0031
# Probabilidade de atenção do token 6 para 7: 0.0002
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0494
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 0.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 1.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 1.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0000
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.0000
# Probabilidade de atenção do token 8 para 10: 0.0000
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 1.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.0000
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 0.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 1.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 4 - Loss: 1.8348
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 1.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 0.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 0.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 1.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.0000
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.9390
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0283
# Probabilidade de atenção do token 2 para 6: 0.0000
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0327
# Probabilidade de atenção do token 2 para 9: 0.0000
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.2589
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0000
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.5575
# Probabilidade de atenção do token 3 para 6: 0.1836
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0000
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 0.0000
# Probabilidade de atenção do token 4 para 4: 0.4850
# Probabilidade de atenção do token 4 para 5: 0.0106
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.5044
# Probabilidade de atenção do token 5 para 0: 0.0000
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.0000
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0000
# Probabilidade de atenção do token 5 para 5: 1.0000
# Probabilidade de atenção do token 5 para 6: 0.0000
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0000
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 0.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0292
# Probabilidade de atenção do token 6 para 5: 0.9149
# Probabilidade de atenção do token 6 para 6: 0.0033
# Probabilidade de atenção do token 6 para 7: 0.0002
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0524
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 0.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 1.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 1.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0000
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.0000
# Probabilidade de atenção do token 8 para 10: 0.0000
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 1.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.0000
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 0.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 1.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 5 - Loss: 1.8260
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 1.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 0.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 0.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 1.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.0000
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.9328
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0312
# Probabilidade de atenção do token 2 para 6: 0.0000
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0360
# Probabilidade de atenção do token 2 para 9: 0.0000
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.2982
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0000
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.4983
# Probabilidade de atenção do token 3 para 6: 0.2035
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0000
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 0.0000
# Probabilidade de atenção do token 4 para 4: 0.4962
# Probabilidade de atenção do token 4 para 5: 0.0110
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.4928
# Probabilidade de atenção do token 5 para 0: 0.0000
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.0000
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0000
# Probabilidade de atenção do token 5 para 5: 1.0000
# Probabilidade de atenção do token 5 para 6: 0.0000
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0000
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 0.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0313
# Probabilidade de atenção do token 6 para 5: 0.9087
# Probabilidade de atenção do token 6 para 6: 0.0037
# Probabilidade de atenção do token 6 para 7: 0.0002
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0562
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 0.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 1.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 1.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0000
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.0000
# Probabilidade de atenção do token 8 para 10: 0.0000
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 1.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.0000
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 0.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 1.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 6 - Loss: 1.8174
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 1.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 0.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 0.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 1.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.0000
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.9261
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0343
# Probabilidade de atenção do token 2 para 6: 0.0000
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0397
# Probabilidade de atenção do token 2 para 9: 0.0000
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.3392
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0000
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.4400
# Probabilidade de atenção do token 3 para 6: 0.2209
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0000
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 0.0000
# Probabilidade de atenção do token 4 para 4: 0.5052
# Probabilidade de atenção do token 4 para 5: 0.0114
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.4834
# Probabilidade de atenção do token 5 para 0: 0.0000
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.0000
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0000
# Probabilidade de atenção do token 5 para 5: 1.0000
# Probabilidade de atenção do token 5 para 6: 0.0000
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0000
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 0.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0338
# Probabilidade de atenção do token 6 para 5: 0.9013
# Probabilidade de atenção do token 6 para 6: 0.0040
# Probabilidade de atenção do token 6 para 7: 0.0002
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0607
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 0.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 1.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 1.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0000
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.0000
# Probabilidade de atenção do token 8 para 10: 0.0000
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 1.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.0000
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 0.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 1.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 7 - Loss: 1.8094
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 1.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 0.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 0.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 1.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.0000
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.9188
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0376
# Probabilidade de atenção do token 2 para 6: 0.0000
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0436
# Probabilidade de atenção do token 2 para 9: 0.0000
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.3811
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0000
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.3842
# Probabilidade de atenção do token 3 para 6: 0.2347
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0000
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 0.0000
# Probabilidade de atenção do token 4 para 4: 0.5121
# Probabilidade de atenção do token 4 para 5: 0.0118
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.4762
# Probabilidade de atenção do token 5 para 0: 0.0000
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.0000
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0000
# Probabilidade de atenção do token 5 para 5: 1.0000
# Probabilidade de atenção do token 5 para 6: 0.0000
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0000
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 0.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0366
# Probabilidade de atenção do token 6 para 5: 0.8927
# Probabilidade de atenção do token 6 para 6: 0.0044
# Probabilidade de atenção do token 6 para 7: 0.0002
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0660
# Probabilidade de atenção do token 7 para 0: 0.0000
# ...
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.0000
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0000
# Probabilidade de atenção do token 5 para 5: 1.0000
# Probabilidade de atenção do token 5 para 6: 0.0000
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0000
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 0.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0397
# Probabilidade de atenção do token 6 para 5: 0.8831
# Probabilidade de atenção do token 6 para 6: 0.0049
# Probabilidade de atenção do token 6 para 7: 0.0002
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0721
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 0.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 1.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 1.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0000
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.0000
# Probabilidade de atenção do token 8 para 10: 0.0000
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 1.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.0000
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 0.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 1.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 9 - Loss: 1.7979
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 1.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 0.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 0.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 1.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.0000
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.9025
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0451
# Probabilidade de atenção do token 2 para 6: 0.0000
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0525
# Probabilidade de atenção do token 2 para 9: 0.0000
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.4594
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0000
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.2909
# Probabilidade de atenção do token 3 para 6: 0.2496
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0000
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 0.0000
# Probabilidade de atenção do token 4 para 4: 0.5195
# Probabilidade de atenção do token 4 para 5: 0.0126
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.4679
# Probabilidade de atenção do token 5 para 0: 0.0000
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.0000
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0000
# Probabilidade de atenção do token 5 para 5: 1.0000
# Probabilidade de atenção do token 5 para 6: 0.0000
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0000
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 0.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0431
# Probabilidade de atenção do token 6 para 5: 0.8724
# Probabilidade de atenção do token 6 para 6: 0.0053
# Probabilidade de atenção do token 6 para 7: 0.0003
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0789
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 0.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 1.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 1.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0000
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.0000
# Probabilidade de atenção do token 8 para 10: 0.0000
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 1.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.0000
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 0.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 1.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Iteração 10 - Loss: 1.7940
# Número de arranjos com repetição em atenção: 121
# Probabilidade de atenção do token 0 para 0: 0.0000
# Probabilidade de atenção do token 0 para 1: 0.0000
# Probabilidade de atenção do token 0 para 2: 0.0000
# Probabilidade de atenção do token 0 para 3: 0.0000
# Probabilidade de atenção do token 0 para 4: 0.0000
# Probabilidade de atenção do token 0 para 5: 1.0000
# Probabilidade de atenção do token 0 para 6: 0.0000
# Probabilidade de atenção do token 0 para 7: 0.0000
# Probabilidade de atenção do token 0 para 8: 0.0000
# Probabilidade de atenção do token 0 para 9: 0.0000
# Probabilidade de atenção do token 0 para 10: 0.0000
# Probabilidade de atenção do token 1 para 0: 0.0000
# Probabilidade de atenção do token 1 para 1: 0.0000
# Probabilidade de atenção do token 1 para 2: 0.0000
# Probabilidade de atenção do token 1 para 3: 0.0000
# Probabilidade de atenção do token 1 para 4: 0.0000
# Probabilidade de atenção do token 1 para 5: 1.0000
# Probabilidade de atenção do token 1 para 6: 0.0000
# Probabilidade de atenção do token 1 para 7: 0.0000
# Probabilidade de atenção do token 1 para 8: 0.0000
# Probabilidade de atenção do token 1 para 9: 0.0000
# Probabilidade de atenção do token 1 para 10: 0.0000
# Probabilidade de atenção do token 2 para 0: 0.0000
# Probabilidade de atenção do token 2 para 1: 0.0000
# Probabilidade de atenção do token 2 para 2: 0.8933
# Probabilidade de atenção do token 2 para 3: 0.0000
# Probabilidade de atenção do token 2 para 4: 0.0000
# Probabilidade de atenção do token 2 para 5: 0.0492
# Probabilidade de atenção do token 2 para 6: 0.0000
# Probabilidade de atenção do token 2 para 7: 0.0000
# Probabilidade de atenção do token 2 para 8: 0.0575
# Probabilidade de atenção do token 2 para 9: 0.0000
# Probabilidade de atenção do token 2 para 10: 0.0000
# Probabilidade de atenção do token 3 para 0: 0.4952
# Probabilidade de atenção do token 3 para 1: 0.0000
# Probabilidade de atenção do token 3 para 2: 0.0000
# Probabilidade de atenção do token 3 para 3: 0.0000
# Probabilidade de atenção do token 3 para 4: 0.0000
# Probabilidade de atenção do token 3 para 5: 0.2536
# Probabilidade de atenção do token 3 para 6: 0.2512
# Probabilidade de atenção do token 3 para 7: 0.0000
# Probabilidade de atenção do token 3 para 8: 0.0000
# Probabilidade de atenção do token 3 para 9: 0.0000
# Probabilidade de atenção do token 3 para 10: 0.0000
# Probabilidade de atenção do token 4 para 0: 0.0000
# Probabilidade de atenção do token 4 para 1: 0.0000
# Probabilidade de atenção do token 4 para 2: 0.0000
# Probabilidade de atenção do token 4 para 3: 0.0000
# Probabilidade de atenção do token 4 para 4: 0.5205
# Probabilidade de atenção do token 4 para 5: 0.0130
# Probabilidade de atenção do token 4 para 6: 0.0000
# Probabilidade de atenção do token 4 para 7: 0.0000
# Probabilidade de atenção do token 4 para 8: 0.0000
# Probabilidade de atenção do token 4 para 9: 0.0000
# Probabilidade de atenção do token 4 para 10: 0.4665
# Probabilidade de atenção do token 5 para 0: 0.0000
# Probabilidade de atenção do token 5 para 1: 0.0000
# Probabilidade de atenção do token 5 para 2: 0.0000
# Probabilidade de atenção do token 5 para 3: 0.0000
# Probabilidade de atenção do token 5 para 4: 0.0000
# Probabilidade de atenção do token 5 para 5: 1.0000
# Probabilidade de atenção do token 5 para 6: 0.0000
# Probabilidade de atenção do token 5 para 7: 0.0000
# Probabilidade de atenção do token 5 para 8: 0.0000
# Probabilidade de atenção do token 5 para 9: 0.0000
# Probabilidade de atenção do token 5 para 10: 0.0000
# Probabilidade de atenção do token 6 para 0: 0.0000
# Probabilidade de atenção do token 6 para 1: 0.0000
# Probabilidade de atenção do token 6 para 2: 0.0000
# Probabilidade de atenção do token 6 para 3: 0.0000
# Probabilidade de atenção do token 6 para 4: 0.0468
# Probabilidade de atenção do token 6 para 5: 0.8606
# Probabilidade de atenção do token 6 para 6: 0.0059
# Probabilidade de atenção do token 6 para 7: 0.0003
# Probabilidade de atenção do token 6 para 8: 0.0000
# Probabilidade de atenção do token 6 para 9: 0.0000
# Probabilidade de atenção do token 6 para 10: 0.0864
# Probabilidade de atenção do token 7 para 0: 0.0000
# Probabilidade de atenção do token 7 para 1: 0.0000
# Probabilidade de atenção do token 7 para 2: 0.0000
# Probabilidade de atenção do token 7 para 3: 0.0000
# Probabilidade de atenção do token 7 para 4: 0.0000
# Probabilidade de atenção do token 7 para 5: 1.0000
# Probabilidade de atenção do token 7 para 6: 0.0000
# Probabilidade de atenção do token 7 para 7: 0.0000
# Probabilidade de atenção do token 7 para 8: 0.0000
# Probabilidade de atenção do token 7 para 9: 0.0000
# Probabilidade de atenção do token 7 para 10: 0.0000
# Probabilidade de atenção do token 8 para 0: 0.0000
# Probabilidade de atenção do token 8 para 1: 0.0000
# Probabilidade de atenção do token 8 para 2: 0.0000
# Probabilidade de atenção do token 8 para 3: 0.0000
# Probabilidade de atenção do token 8 para 4: 0.0000
# Probabilidade de atenção do token 8 para 5: 1.0000
# Probabilidade de atenção do token 8 para 6: 0.0000
# Probabilidade de atenção do token 8 para 7: 0.0000
# Probabilidade de atenção do token 8 para 8: 0.0000
# Probabilidade de atenção do token 8 para 9: 0.0000
# Probabilidade de atenção do token 8 para 10: 0.0000
# Probabilidade de atenção do token 9 para 0: 0.0000
# Probabilidade de atenção do token 9 para 1: 0.0000
# Probabilidade de atenção do token 9 para 2: 0.0000
# Probabilidade de atenção do token 9 para 3: 0.0000
# Probabilidade de atenção do token 9 para 4: 0.0000
# Probabilidade de atenção do token 9 para 5: 1.0000
# Probabilidade de atenção do token 9 para 6: 0.0000
# Probabilidade de atenção do token 9 para 7: 0.0000
# Probabilidade de atenção do token 9 para 8: 0.0000
# Probabilidade de atenção do token 9 para 9: 0.0000
# Probabilidade de atenção do token 9 para 10: 0.0000
# Probabilidade de atenção do token 10 para 0: 0.0000
# Probabilidade de atenção do token 10 para 1: 0.0000
# Probabilidade de atenção do token 10 para 2: 0.0000
# Probabilidade de atenção do token 10 para 3: 0.0000
# Probabilidade de atenção do token 10 para 4: 0.0000
# Probabilidade de atenção do token 10 para 5: 1.0000
# Probabilidade de atenção do token 10 para 6: 0.0000
# Probabilidade de atenção do token 10 para 7: 0.0000
# Probabilidade de atenção do token 10 para 8: 0.0000
# Probabilidade de atenção do token 10 para 9: 0.0000
# Probabilidade de atenção do token 10 para 10: 0.0000
# Ação decidida pelo MiniCórtex: Reduzir Atenção
# Distribuição de probabilidades: [0.321 0.374 0.    0.306 0.   ]
